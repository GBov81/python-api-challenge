# %%
# Import necessary libraries: pandas for data handling, requests for API requests, folium for map visualization.
import pandas as pd
import requests
import folium
import sys

# Load the city data from the CSV file.
city_data_df = pd.read_csv('https://raw.githubusercontent.com/GBov81/python-api-challenge/main/output_data/cities.csv')

# Create a map centered on a location (e.g., the first city in the DataFrame).
m = folium.Map(location=[city_data_df['Lat'].iloc[0], city_data_df['Lng'].iloc[0]], zoom_start=5)

# Add city points to the map based on humidity and display the map.
for index, row in city_data_df.iterrows():
    folium.CircleMarker(
        location=[row['Lat'], row['Lng']],
        radius=row['Humidity'] / 5,  # Adjust the size of the circle marker based on humidity.
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.6,
        popup=f"City: {row['City']}<br>Humidity: {row['Humidity']}%"
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e590a979f841578f05d8f218c8d339e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e590a979f841578f05d8f218c8d339e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e590a979f841578f05d8f218c8d339e4 = L.map(
#                 &quot;map_e590a979f841578f05d8f218c8d339e4&quot;,
#                 {
#                     center: [18.3851, 42.4509],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35240e68ba96e018c632525d34fcdf06 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e590a979f841578f05d8f218c8d339e4);
#
#
#             var circle_marker_b8b4fab32d56ba1dea8c122087bcf72b = L.circleMarker(
#                 [18.3851, 42.4509],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e590a979f841578f05d8f218c8d339e4);
#
#
#         var popup_ea67838797957588c90e38e70efe6bfc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81c09a8f0f5a505f3b6694e3c0fbc75d = $(`&lt;div id=&quot;html_81c09a8f0f5a505f3b6694e3c0fbc75d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: faya&lt;br&gt;Humidity: 35%&lt;/div&gt;`)[0];
#                 popup_ea67838797957588c90e38e70efe6bfc.setContent(html_81c09a8f0f5a505f3b6694e3c0fbc75d);
#
#
#
#         circle_marker_b8b4fab32d56ba1dea8c122087bcf72b.bindPopup(popup_ea67838797957588c90e38e70efe6bfc)
#         ;
#
#
#
#
#             var circle_marker_7123a3f8916dae2363e8d8b40df43984 = L.circleMarker(
#                 [58.0948, 6.8047],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e590a979f841578f05d8f218c8d339e4);
#
#
#         var popup_93093cd8012d22e13d38c4b179ed139f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fbd86ef1cc6a85c8c4eab0b0378e57cd = $(`&lt;div id=&quot;html_fbd86ef1cc6a85c8c4eab0b0378e57cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: farsund&lt;br&gt;Humidity: 100%&lt;/div&gt;`)[0];
#                 popup_93093cd8012d22e13d38c4b179ed139f.setContent(html_fbd86ef1cc6a85c8c4eab0b0378e57cd);
#
#
#
#         circle_marker_7123a3f8916dae2363e8d8b40df43984.bindPopup(popup_93093cd8012d22e13d38c4b179ed139f)
#         ;
#
#
#
#
#             var circle_marker_4434bc0c5720b7bd96ad4093525ab5da = L.circleMarker(
#                 [-42.7826, 147.0587],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e590a979f841578f05d8f218c8d339e4);
#
#
#         var popup_7dd13d7a990816d674b1661cd15b7a8b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d2965c0862672620e057840059a845ba = $(`&lt;div id=&quot;html_d2965c0862672620e057840059a845ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: new norfolk&lt;br&gt;Humidity: 58%&lt;/div&gt;`)[0];
#                 popup_7dd13d7a990816d674b1661cd15b7a8b.setContent(html_d2965c0862672620e057840059a845ba);
#
#
#
#         circle_marker_4434bc0c5720b7bd96ad4093525ab5da.bindPopup(popup_7dd13d7a990816d674b1661cd15b7a8b)
#         ;
#
#
#
#
#             var circle_marker_4a976800d1c057db85a7bb1e1beb328b = L.circleMarker(
#                 [42.097, -79.2353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: nu
